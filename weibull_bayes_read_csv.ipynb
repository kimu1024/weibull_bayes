# %% [markdown]
# csvファイルを読み取り、ベイズ推定を行う

# %%
#サンプルデータ
import pandas as pd

sample = pd.read_csv('test_sample.csv')
sample
# Out:
#     time  censored
# 0     10         0
# 1     20         0
# 2     30         0
# 3     50         0
# 4     51         0
# 5     53         0
# 6     55         0
# 7     60         0
# 8     63         0
# 9     68         0
# 10    68         0
# 11    78         0
# 12    78         0
# 13    79         0
# 14    82         0
# 15    85         0
# 16    95         0
# 17   110         0
# 18   155         0
# 19   200         1

# %%
#プログラムの使用例
from modules import weibull_bayes
# %matplotlib inline

wb = weibull_bayes.Weibull_bayes(filename='test_sample.csv')
samples = wb.mcmc(5000)
wb.calculate_credible_interbal_of_failure_probability()
wb.make_plot(credible_interbal=0.90,show=True, save=True, save_filename='test_result.png')
# Out:
# Sample: 100%|███████████████████████████████████████| 5500/5500 [01:32, 59.41it/s, step size=7.24e-01, acc. prob=0.936]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#      mu[0]      1.68      0.30      1.67      1.19      2.17   2525.81      1.00
#     eta[0]     86.74     13.52     85.72     65.05    107.15   1817.84      1.00
#
# Number of divergences: 0
# (<Figure size 720x360 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002854E251B08>,
# ...
#        dtype=object))
